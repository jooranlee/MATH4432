# %%
# %%shell
# jupyter nbconvert --to html "/content/Solution for HW1.ipynb"
# Out:
# [NbConvertApp] Converting notebook /content/Solution for HW1.ipynb to html
# [NbConvertApp] Writing 2377439 bytes to /content/Solution for HW1.html
